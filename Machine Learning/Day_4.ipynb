# %% [markdown]
# ## API KEY:

# %%
import pandas as pd
import requests

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=ee0613e81f2b8297033ecb3c4d61d421&language=en-US&page=1')

# %% [markdown]
# ### 6 c=Column select code

# %%
df = pd.DataFrame(response.json()['results'])[['id','title','release_date','overview','popularity','vote_average']]

# %%
df.head()
# Out:
#         id                     title release_date  \
# 0  1007757                   Swapped   2026-05-01
# 1      278  The Shawshank Redemption   1994-09-23
# 2      238             The Godfather   1972-03-14
# 3   687163         Project Hail Mary   2026-03-15
# 4      240     The Godfather Part II   1974-12-20
#
#                                             overview  popularity  vote_average
# 0  A small woodland creature and a majestic bird,...    216.7283         8.970
# 1  Imprisoned in the 1940s for the double murder ...     67.7713         8.722
# 2  Spanning the years 1945 to 1955, a chronicle o...     43.1905         8.687
# 3  Science teacher Ryland Grace wakes up on a spa...    248.3935         8.655
# 4  In the continuing saga of the Corleone crime f...     28.6290         8.571

# %% [markdown]
# ### Get a data from page 5

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=ee0613e81f2b8297033ecb3c4d61d421&language=en-US&page=5')

# %%
df1 = pd.DataFrame(response.json()['results'])[['id','title','release_date','overview','popularity','vote_average']]
df1
# Out:
#          id                                           title release_date  \
# 0     92321                              Hotarubi no Mori e   2011-09-17
# 1     18491  Neon Genesis Evangelion: The End of Evangelion   1997-07-19
# 2      8587                                   The Lion King   1994-06-15
# 3       975                                  Paths of Glory   1957-10-25
# 4   1317149                                         I Swear   2025-09-22
# 5     92060                      Michael Jackson's Thriller   1983-11-21
# 6       901                                     City Lights   1931-02-06
# 7    637920                           Miracle in Cell No. 7   2019-10-10
# 8     15804                           A Brighter Summer Day   1991-07-27
# 9       603                                      The Matrix   1999-03-31
# 10  1356039                                   Counterattack   2025-02-27
# 11   630566                                          Clouds   2020-10-09
# ...

# %%
df1.shape
# Out:
# (20, 6)

# %%
df1.to_csv('movies.csv')

# %%
df1
# Out:
#          id                                           title release_date  \
# 0     92321                              Hotarubi no Mori e   2011-09-17
# 1     18491  Neon Genesis Evangelion: The End of Evangelion   1997-07-19
# 2      8587                                   The Lion King   1994-06-15
# 3       975                                  Paths of Glory   1957-10-25
# 4   1317149                                         I Swear   2025-09-22
# 5     92060                      Michael Jackson's Thriller   1983-11-21
# 6       901                                     City Lights   1931-02-06
# 7    637920                           Miracle in Cell No. 7   2019-10-10
# 8     15804                           A Brighter Summer Day   1991-07-27
# 9       603                                      The Matrix   1999-03-31
# 10  1356039                                   Counterattack   2025-02-27
# 11   630566                                          Clouds   2020-10-09
# ...

# %%
df.to_csv('movies_page1.csv')

# %%
df
# Out:
#          id                                           title release_date  \
# 0     92321                              Hotarubi no Mori e   2011-09-17
# 1     18491  Neon Genesis Evangelion: The End of Evangelion   1997-07-19
# 2      8587                                   The Lion King   1994-06-15
# 3       975                                  Paths of Glory   1957-10-25
# 4   1317149                                         I Swear   2025-09-22
# 5     92060                      Michael Jackson's Thriller   1983-11-21
# 6       901                                     City Lights   1931-02-06
# 7    637920                           Miracle in Cell No. 7   2019-10-10
# 8     15804                           A Brighter Summer Day   1991-07-27
# 9       603                                      The Matrix   1999-03-31
# 10  1356039                                   Counterattack   2025-02-27
# 11   630566                                          Clouds   2020-10-09
# ...
