# %% [markdown]
# ## EDA BIVARIATE ANALYSIS

# %%
import pandas as pd

# %% [markdown]
# ### Import Dataset | Titanic

# %%
df = pd.read_csv('train (3).csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ### Pandas Profiling

# %%
# %pip install ydata-profiling
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 26.1.2
# [notice] To update, run: C:\Users\HP\AppData\Local\Programs\Python\Python311\python.exe -m pip install --upgrade pip

# %% [markdown]
# ### Import Profile Report

# %%
import numba
import llvmlite

print(numba.__version__)
print(llvmlite.__version__)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\llvmlite\binding\ffi.py:141, in _lib_wrapper.__getattr__(self, name)
#     140 try:
# --> 141     return self._fntab[name]
#     142 except KeyError:
#     143     # Lazily wraps new functions as they are requested
#
# KeyError: 'LLVMPY_AddSymbol'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\llvmlite\binding\ffi.py:122, in _lib_wrapper._load_lib(self)
#     119 with _suppress_cleanup_errors(_importlib_resources_path(
#     120         __name__.rpartition(".")[0],
#     121         get_library_name())) as lib_path:
# --> 122     self._lib_handle = ctypes.CDLL(str(lib_path))
# ...

# %%
import sys
print(sys.executable)
print(sys.version)
# Out:
# C:\Users\HP\AppData\Local\Programs\Python\Python311\python.exe
# 3.11.0 (main, Oct 24 2022, 18:26:48) [MSC v.1933 64 bit (AMD64)]

# %%
import sys

# !{sys.executable} -m pip show numba
# !{sys.executable} -m pip show llvmlite
# Out:
# Name: numba
# Version: 0.61.0
# Summary: compiling Python code using LLVM
# Home-page: https://numba.pydata.org
# Author:
# Author-email:
# License: BSD
# Location: C:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages
# Requires: llvmlite, numpy
# Required-by: ydata-profiling
# Name: llvmlite
# Version: 0.44.0
# Summary: lightweight wrapper around basic LLVM functionality
# Home-page: http://llvmlite.readthedocs.io
# Author:
# Author-email:
# License: BSD
# Location: C:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages
# Requires:
# Required-by: numba

# %%
import os

dll_path = r"C:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\llvmlite\binding\llvmlite.dll"

print("Exists:", os.path.exists(dll_path))
print(dll_path)
# Out:
# Exists: True
# C:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\llvmlite\binding\llvmlite.dll

# %%
import sys

# !{sys.executable} -m pip uninstall -y llvmlite numba
# !{sys.executable} -m pip cache purge
# !{sys.executable} -m pip install --no-cache-dir llvmlite==0.44.0
# !{sys.executable} -m pip install --no-cache-dir numba==0.61.0
# Out:
# Found existing installation: llvmlite 0.44.0
# Uninstalling llvmlite-0.44.0:
#   Successfully uninstalled llvmlite-0.44.0
# Found existing installation: numba 0.61.0
# Uninstalling numba-0.61.0:
#   Successfully uninstalled numba-0.61.0
# Files removed: 0 (0 bytes)
# WARNING: No matching packages
# ...
#    ---------------------------------------- 0.0/30.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/30.3 MB ? eta -:--:--
#     --------------------------------------- 0.5/30.3 MB 2.1 MB/s eta 0:00:15
#    - -------------------------------------- 0.8/30.3 MB 2.0 MB/s eta 0:00:15
#    - -------------------------------------- 1.0/30.3 MB 1.5 MB/s eta 0:00:20
#    - -------------------------------------- 1.0/30.3 MB 1.5 MB/s eta 0:00:20
#    - -------------------------------------- 1.3/30.3 MB 1.2 MB/s eta 0:00:25
#    - -------------------------------------- 1.3/30.3 MB 1.2 MB/s eta 0:00:25
#    - -------------------------------------- 1.3/30.3 MB 1.2 MB/s eta 0:00:25
# ...

# %%
import sys

# !{sys.executable} -m pip install --no-cache-dir llvmlite==0.44.0
# !{sys.executable} -m pip install --no-cache-dir numba==0.61.0

# %%
import numba
import llvmlite

print("Numba:", numba.__version__)
print("llvmlite:", llvmlite.__version__)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\llvmlite\binding\ffi.py:141, in _lib_wrapper.__getattr__(self, name)
#     140 try:
# --> 141     return self._fntab[name]
#     142 except KeyError:
#     143     # Lazily wraps new functions as they are requested
#
# KeyError: 'LLVMPY_AddSymbol'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\llvmlite\binding\ffi.py:122, in _lib_wrapper._load_lib(self)
#     119 with _suppress_cleanup_errors(_importlib_resources_path(
#     120         __name__.rpartition(".")[0],
#     121         get_library_name())) as lib_path:
# --> 122     self._lib_handle = ctypes.CDLL(str(lib_path))
# ...
